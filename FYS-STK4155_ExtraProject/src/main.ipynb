# %%
from load_data import load_data
import numpy as np
from sklearn.neural_network import MLPClassifier, MLPRegressor
from accuracy_score import accuracy_score
from sklearn.model_selection import train_test_split
from GridSearch import *
import pandas as pd
from mean_square_error import MSE
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# %%
headers, data = load_data()
Y = data[:,4]
X = np.delete(data,4,1)
headers = np.delete(headers, 4)

#Changing from string to integer represenations
#Making tables to keep track of which integer represents which string
idx_change = [0,2,3]
lookupTable = []
for idx in range(len(headers)):
    tmp = []
    if idx in idx_change:
        tmp, X[:,idx] = np.unique(data[:,idx], return_inverse=True)
    lookupTable.append(tmp)


print(headers)
X[:,7] = np.array([s.replace(",", "") for s in X[:,7]])
X = X.astype(np.float64)
#Checking that all types are floats now
for i in range(len(X[0])):
    print(type(X[0][i]))

X[:,7] /= 1000 #dividing to get slightly smaller numbers to avoid errors

#remove nan from Y and replacing with 0
for i in range(len(Y)):
    if Y[i] != Y[i]:
        Y[i] = 0

#Analyzing data, and findig mean
print(np.max(Y), np.min(Y), np.mean(Y))
y_mean = np.mean(Y)
# Out:
# ['country' 'year' 'sex' 'age' 'population' 'suicides/100k pop'
#  'HDI for year' ' gdp_for_year ($) ' 'gdp_per_capita ($)']
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# [2.15662490e+06 2.15662490e+06 2.15662490e+06 ... 1.95000000e+10
#  6.42339669e+07 6.20813233e+07]
# 22338.0 0.0 228.1753054540874

# %%
#Changing to classification problem
Y_class = np.where(Y > y_mean, 1, 0)
print(Y_class)
# Out:
# [0 0 0 ... 1 0 0]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y_class, test_size = 0.25) #Splitting data into train and test

# %%
model = MLPClassifier()
model.fit(X_train, Y_train)
# Out:
# MLPClassifier()

# %%
Y_pred = model.predict(X_test)
print(accuracy_score(Y_pred, Y_test))
# Out:
# [[6306  916]
#  [ 257  460]]
# 0.8522483940042827

# %%
grid_search_hyperparameters_MLP(X_train, X_test, Y_train, Y_test, "Accuracy score MLP (relu)", func="relu", verbose=True)
# Out:
# alpha:1e-05, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.0001 gives accuracy 0.39337448041315026
# alpha:1e-05, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.01 gives accuracy 0.7945585086282907
# alpha:1e-05, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1e-06 gives accuracy 0.48494772641390604
# alpha:0.001, momentum :1e-05 gives accuracy 0.7101650081874291
# alpha:0.001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1.0 gives accuracy 0.8194986774152916
# alpha:0.01, momentum :1e-06 gives accuracy 0.6435319309736742
# alpha:0.01, momentum :1e-05 gives accuracy 0.8182390729310997
# alpha:0.01, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.001 gives accuracy 0.7721375488096738
# alpha:0.01, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1e-06 gives accuracy 0.8249149766973171
# alpha:0.1, momentum :1e-05 gives accuracy 0.8200025192089684
# alpha:0.1, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.001 gives accuracy 0.6674644161733215
# alpha:0.1, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-05 gives accuracy 0.8194986774152916
# alpha:1.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.001 gives accuracy 0.7959440735609019
# alpha:1.0, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.1 gives accuracy 0.570852752235798
# alpha:1.0, momentum :1.0 gives accuracy 0.5635470462274845
# alpha:10.0, momentum :1e-06 gives accuracy 0.7123063358105555
# alpha:10.0, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.01 gives accuracy 0.8186169542763573
# alpha:10.0, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1.0 gives accuracy 0.47726413906033505

# %%
grid_search_hyperparameters_MLP(X_train, X_test, Y_train, Y_test, "Accuracy score MLP (logistic)", func="logistic", verbose=True)
# Out:
# alpha:1e-05, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1.0 gives accuracy 0.8187429147247764

# %%
grid_search_hyperparameters_MLP(X_train, X_test, Y_train, Y_test, "Accuracy score MLP (tanh)", func="tanh", verbose=True)
# Out:
# alpha:1e-05, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:1e-05, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.0001, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.001, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.01, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:0.1, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:1.0, momentum :1.0 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1e-06 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1e-05 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.0001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.001 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.01 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :0.1 gives accuracy 0.8187429147247764
# alpha:10.0, momentum :1.0 gives accuracy 0.8187429147247764

# %% [markdown]
# We now want to look at F1 scores for a more accurate measurement.

# %%
from sklearn.metrics import f1_score
model = MLPClassifier(activation="relu").fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print(f1_score(Y_test, Y_pred))
# Out:
# 0.5511864406779662

# %%
print(accuracy_score(Y_test,Y_pred))
print(f1_score(Y_test, Y_pred))
# Out:
# [[5802  786]
#  [ 538  813]]
# 0.833228366292984
# 0.5511864406779662

# %%
grid_search_hyperparameters_MLP_F1(X_train, X_test, Y_train, Y_test, "F1-score MLP (relu)", func="relu", verbose=True)
# Out:
# alpha:1e-05, momentum :1e-06 gives f1 score 0.5546588407923698
# alpha:1e-05, momentum :1e-05 gives f1 score 0.18534752661239826
# alpha:1e-05, momentum :0.0001 gives f1 score 0.5583333333333333
# alpha:1e-05, momentum :0.001 gives f1 score 0.0
# alpha:1e-05, momentum :0.01 gives f1 score 0.1789838337182448
# alpha:1e-05, momentum :0.1 gives f1 score 0.6025559105431311
# alpha:1e-05, momentum :1.0 gives f1 score 0.6015473887814313
# alpha:0.0001, momentum :1e-06 gives f1 score 0.5991706979958534
# alpha:0.0001, momentum :1e-05 gives f1 score 0.16449704142011834
# alpha:0.0001, momentum :0.0001 gives f1 score 0.5914770906760652
# alpha:0.0001, momentum :0.001 gives f1 score 0.548317823908375
# alpha:0.0001, momentum :0.01 gives f1 score 0.5337883959044368
# alpha:0.0001, momentum :0.1 gives f1 score 0.0
# alpha:0.0001, momentum :1.0 gives f1 score 0.03968816442239547
# alpha:0.001, momentum :1e-06 gives f1 score 0.0
# alpha:0.001, momentum :1e-05 gives f1 score 0.6068281938325991
# alpha:0.001, momentum :0.0001 gives f1 score 0.5276020074187213
# alpha:0.001, momentum :0.001 gives f1 score 0.514026402640264
# alpha:0.001, momentum :0.01 gives f1 score 0.49198868991517436
# alpha:0.001, momentum :0.1 gives f1 score 0.0
# alpha:0.001, momentum :1.0 gives f1 score 0.5644551392231008
# alpha:0.01, momentum :1e-06 gives f1 score 0.5124752475247524
# alpha:0.01, momentum :1e-05 gives f1 score 0.29982964224872233
# alpha:0.01, momentum :0.0001 gives f1 score 0.0
# alpha:0.01, momentum :0.001 gives f1 score 0.600275671950379
# alpha:0.01, momentum :0.01 gives f1 score 0.5490725126475549
# alpha:0.01, momentum :0.1 gives f1 score 0.11290322580645161
# alpha:0.01, momentum :1.0 gives f1 score 0.6078553615960101
# alpha:0.1, momentum :1e-06 gives f1 score 0.5550292560601838
# alpha:0.1, momentum :1e-05 gives f1 score 0.017241379310344827
# alpha:0.1, momentum :0.0001 gives f1 score 0.5813546613346664
# alpha:0.1, momentum :0.001 gives f1 score 0.5524556144800554
# alpha:0.1, momentum :0.01 gives f1 score 0.5534297713485767
# alpha:0.1, momentum :0.1 gives f1 score 0.604851089960086
# alpha:0.1, momentum :1.0 gives f1 score 0.5184570717544588
# alpha:1.0, momentum :1e-06 gives f1 score 0.5802332037756802
# alpha:1.0, momentum :1e-05 gives f1 score 0.6100362756952842
# alpha:1.0, momentum :0.0001 gives f1 score 0.0
# alpha:1.0, momentum :0.001 gives f1 score 0.5434697855750487
# alpha:1.0, momentum :0.01 gives f1 score 0.0
# alpha:1.0, momentum :0.1 gives f1 score 0.5842196388820183
# alpha:1.0, momentum :1.0 gives f1 score 0.6058252427184466
# alpha:10.0, momentum :1e-06 gives f1 score 0.5264790604919122
# alpha:10.0, momentum :1e-05 gives f1 score 0.5494505494505494
# alpha:10.0, momentum :0.0001 gives f1 score 0.39697732997481106
# alpha:10.0, momentum :0.001 gives f1 score 0.5421542870790541
# alpha:10.0, momentum :0.01 gives f1 score 0.5539240506329114
# alpha:10.0, momentum :0.1 gives f1 score 0.491664992970476
# alpha:10.0, momentum :1.0 gives f1 score 0.0

# %% [markdown]
# We now want to analyze the F1-score for all activation functions with different sample sizes

# %%
M_list = [100,1000,2000, 3000, 4000, 5000, 10000]
length = len(M_list)
tanh_arr = np.zeros(length)
relu_arr = np.zeros(length)
logistic_arr = np.zeros(length)

for i,M in enumerate(M_list):
    print(i)
    n = len(Y_class)
    m = int(n/M)
    random_index = np.random.randint(m)*M   
    new_X = X[random_index:random_index+M]
    new_Y = Y_class[random_index:random_index+M]

    model = MLPClassifier(activation="tanh", max_iter=10000)
    model.fit(new_X, new_Y)
    Y_pred = model.predict(X)
    acc = f1_score(Y_pred, Y_class)
    tanh_arr[i] = acc

    model = MLPClassifier(activation="logistic", max_iter=10000)
    model.fit(new_X, new_Y)
    Y_pred = model.predict(X)
    acc = f1_score(Y_pred, Y_class)
    logistic_arr[i] = acc

    model = MLPClassifier(activation="relu", max_iter=10000)
    model.fit(new_X, new_Y)
    Y_pred = model.predict(X)
    acc = f1_score(Y_pred, Y_class)
    relu_arr[i] = acc

plt.plot(M_list, relu_arr, label="relu")
plt.plot(M_list, logistic_arr, label="logistic")
plt.plot(M_list, tanh_arr, label="tanh")
plt.ylabel("f1-score")
plt.xlabel("sample size")
plt.legend()
plt.savefig("../figures/f1_scores")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# Now we test the random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(random_state=1)
forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
Y_pred = forest.predict(X_test)
print(accuracy_score(Y_pred, Y_test))
print(f1_score(Y_pred, Y_test))
# Out:
# [[6576   24]
#  [  12 1327]]
# 0.995465423856909
# 0.9866171003717472

# %% [markdown]
# Now removing "suicides per 100k pop", since it gives away too much information.

# %%
new_X_train = np.delete(X_train, 5, 1)
new_X_test = np.delete(X_test, 5, 1)
new_X_Full = np.delete(X,5,1)
new_headers = np.delete(headers, 5)
print(new_headers)

forest = RandomForestClassifier(random_state=1)
forest.fit(new_X_train,Y_train)
Y_pred = forest.predict(new_X_test)
print(accuracy_score(Y_pred, Y_test))
print(f1_score(Y_pred, Y_test))
# Out:
# ['country' 'year' 'sex' 'age' 'population' 'HDI for year'
#  ' gdp_for_year ($) ' 'gdp_per_capita ($)']
# [[6538   98]
#  [  50 1253]]
# 0.9813578536339589
# 0.9442351168048229

# %%
importances = forest.feature_importances_
std = np.std(importances)
forest_importances = pd.Series(importances, index=new_headers)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using Forest of Trees")
ax.set_ylabel("Importance of feature")
fig.tight_layout()
plt.savefig("../figures/Feature_importance.png")

# %% [markdown]
# Here we can see that population is the biggest contributor to number of suicides. This is to be expected, since the bigger the population, the more people there are, and the bigger the number of suicides get.

# %% [markdown]
# We now analyze f1-score for random forest classifier for the same sample sizes as we did for MLP

# %%
forest_arr = np.zeros(len(M_list))
for i,M in enumerate(M_list):
    print(i)
    n = len(Y)
    m = int(n/M)
    random_index = np.random.randint(m)*M   
    new_X = new_X_Full[random_index:random_index+M]
    new_Y = Y_class[random_index:random_index+M]

    forest.fit(new_X, new_Y)
    Y_pred = forest.predict(new_X_Full)
    acc = f1_score(Y_class, Y_pred)
    forest_arr[i] = acc

plt.plot(M_list, forest_arr)
plt.xlabel("sample size")
plt.ylabel("f1-score")
plt.savefig("../figures/f1_score_forest")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# We now want to study which age groups and which countries have the highest suicide rates.
# Here we use death rate instead of total number of deaths, since it gives a better indication on suicides.

# %%
print(headers)
# Out:
# ['country' 'year' 'sex' 'age' 'population' 'suicides/100k pop'
#  'HDI for year' ' gdp_for_year ($) ' 'gdp_per_capita ($)']

# %%
Y_deathrate = X[:,5] #Using deathrate

countries = X[:,0]
Age = X[:,3] 
genders = X[:,2]

deaths_age = {i:0 for i in np.unique(Age)}
deaths_countries = {i:0 for i in np.unique(countries)}
deaths_genders = {i:0 for i in np.unique(genders)}

#Finding total deathrate for each unique element in each feature
for i in range(len(Y)):
    deaths_age[Age[i]] += Y_deathrate[i]
    deaths_countries[countries[i]] += Y_deathrate[i]
    deaths_genders[genders[i]] += Y_deathrate[i]

# %% [markdown]
# We now want to use the death rates we found for each feature to analyze the data and look at what it sais.

# %%
import heapq
top_10 = heapq.nlargest(10, deaths_countries.items(), key=lambda i: i[1])
bottom_10 = heapq.nsmallest(10, deaths_countries.items(), key=lambda i: i[1])
print(top_10)
top_10_list = [lookupTable[0][int(item[0])] for item in top_10]

plt.bar([lookupTable[0][int(item[0])] for item in top_10], [item[1] for item in top_10])
plt.gcf()
plt.tight_layout()
plt.xticks(rotation='vertical')
plt.ylabel("number of suicides per 100 000")
plt.savefig("../figures/TOP_10_COUNTRIES.png",bbox_inches='tight')
plt.show()

plt.bar([lookupTable[0][int(item[0])] for item in bottom_10], [item[1] for item in bottom_10])
plt.gcf()
plt.tight_layout()
plt.xticks(rotation='vertical')
plt.ylabel("number of suicides per 100 000")
plt.savefig("../figures/BOTTOM_10_COUNTRIES.png",bbox_inches='tight')
plt.show()
# Out:
# [(82.0, 19265.354105444992), (85.0, 11327.335292240004), (59.0, 10685.115617238993), (45.0, 10205.526297871993), (53.0, 9572.178273995993), (6.0, 9128.374664240999), (107.0, 8972.677880563995), (51.0, 8056.612843291), (37.0, 7967.2658575159985), (12.0, 7931.355457877004)]

# %%
plt.bar(range(len(lookupTable[0])), deaths_countries.values())
plt.ylabel("number of suicides per 100 000")
plt.xlabel("countries, labeled by numbers")
plt.savefig("../figures/COUNTRIES_SUICIDES.png",bbox_inches='tight')

# %%
plt.bar(lookupTable[3], deaths_age.values())
plt.gcf()
plt.tight_layout()
plt.ylabel("number of suicides per 100 000")
plt.xlabel("age groups")
plt.xticks(rotation='vertical')
plt.savefig("../figures/AGE_DEATHS.png",bbox_inches='tight')
plt.show()

# %%
plt.bar(lookupTable[2], deaths_genders.values())
plt.gcf()
plt.tight_layout()
plt.xticks(rotation='vertical')
plt.ylabel("number of suicides per 100 000")
plt.xlabel("genders")
plt.savefig("../figures/GENDER_DEATHS.png",bbox_inches='tight')
plt.show()

# %% [markdown]
# We now want to look at GDP per capita and suicide rates

# %%
Y_copy = np.copy(Y_deathrate)
GDP_yearly = X[:,7].copy()

tmp = GDP_yearly.argsort()
GDP_yearly.sort()
Y_copy = Y_copy[tmp]

plt.plot(GDP_yearly,Y_copy)
plt.xlabel("GDP yearly")
plt.ylabel("Suicides per 100k population")
plt.savefig("../figures/DEATHS_GDP_YEAR.png",bbox_inches='tight')

# %%
Y_copy = np.copy(Y_deathrate)
GDP = X[:,8].copy() #GDP per capita

tmp = GDP.argsort()
GDP.sort()
Y_copy = Y_copy[tmp]

plt.plot(GDP,Y_copy)
plt.xlabel("GDP per capita")
plt.ylabel("Suicides per 100k population")
plt.savefig("../figures/DEATHS_GDP_POP.png",bbox_inches='tight')

# %% [markdown]
# Here we can see a clear indicator that GDP per capita does matter for the suicide rate of the population.
# We now want to use some linear regression to try to analyze this data.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

lin = LinearRegression()
poly = PolynomialFeatures(degree=10)
X_poly = poly.fit_transform(GDP.reshape(-1,1))
lin.fit(X_poly, Y_copy)


plt.plot(GDP, lin.predict(X_poly))
plt.xlabel("GDP per capita")
plt.ylabel("Suicides per 100k population")
plt.savefig("../figures/REGRESSION_GDP.png",bbox_inches='tight')
plt.show()
