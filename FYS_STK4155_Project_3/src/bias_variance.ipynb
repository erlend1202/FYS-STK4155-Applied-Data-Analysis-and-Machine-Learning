# %% [markdown]
# # Analysis of the bias-variance tradeoff

# %% [markdown]
# ### Importing libraries

# %%
from sample_data import create_data_samples, DataSamplesType
from linear_model import LinearModel, LinearModelType
from design_matrix import create_design_matrix
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import numpy as np
import warnings

# %% [markdown]
# ### Ignoring spesific warnings

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Loading dataset

# %%
x, y, z = create_data_samples(DataSamplesType.TEST)

# %% [markdown]
# ### Linear regression

# %%
max_polynominal = 12
test_size = 0.2
n_bootstraps = 100

ols_model = LinearModel(LinearModelType.OLS)
ridge_model = LinearModel(LinearModelType.RIDGE)
lasso_model = LinearModel(LinearModelType.LASSO)

ridge_model.set_lambda(0.001)
lasso_model.set_lambda(0.001)

x = x.ravel()
y = y.ravel()
z = z.ravel().reshape(-1,1)
x_train, x_test, y_train, y_test, z_train, z_test = train_test_split(x, y, z, test_size=test_size)

errors = np.zeros((3, max_polynominal))
biases = np.zeros((3, max_polynominal))
variances = np.zeros((3, max_polynominal))

for current_polynominal in range(1, max_polynominal + 1):
    print(f"at polynomial {current_polynominal} out of {max_polynominal}")
    
    # Creating design matrix 
    X_train = create_design_matrix(x_train, y_train, current_polynominal)

    X_test = create_design_matrix(x_test, y_test, current_polynominal)
    
    predictions = np.zeros((3, len(z_test), n_bootstraps))

    for i in range(n_bootstraps):
        X_, z_ = resample(X_train, z_train)
        # Creating a fit for the models with the data
        ols_model.fit(X_, z_)
        ridge_model.fit(X_, z_)
        lasso_model.fit(X_, z_)

        # Creating predictions with the models
        predictions[0, :, i] = ols_model.predict(X_test).ravel()
        predictions[1, :, i] = ridge_model.predict(X_test).ravel()
        predictions[2, :, i] = lasso_model.predict(X_test).ravel()

    errors[0, current_polynominal - 1] = np.mean(np.mean((z_test - predictions[0, :])**2, axis=1, keepdims=True))
    biases[0, current_polynominal - 1] = np.mean((z_test - np.mean(predictions[0, :], axis=1, keepdims=True))**2)
    variances[0, current_polynominal - 1] = np.mean( np.var(predictions[0, :], axis=1, keepdims=True))

    errors[1, current_polynominal - 1] = np.mean(np.mean((z_test - predictions[1, :])**2, axis=1, keepdims=True))
    biases[1, current_polynominal - 1] = np.mean((z_test - np.mean(predictions[1, :], axis=1, keepdims=True))**2)
    variances[1, current_polynominal - 1] = np.mean( np.var(predictions[1, :], axis=1, keepdims=True))

    errors[2, current_polynominal - 1] = np.mean(np.mean((z_test - predictions[1, :])**2, axis=1, keepdims=True))
    biases[2, current_polynominal - 1] = np.mean((z_test - np.mean(predictions[1, :], axis=1, keepdims=True))**2)
    variances[2, current_polynominal - 1] = np.mean( np.var(predictions[1, :], axis=1, keepdims=True))

plt.figure()
plt.title("OLS bias-variance")
plt.plot(errors[0, :], label="Error")
plt.plot(biases[0, :], label="Bias")
plt.plot(variances[0, :], label="Variance")
plt.legend()
#plt.savefig("../figures/ols_bias_variance")


plt.figure()
plt.title("Ridge bias-variance")
plt.plot(errors[1, :], label="Error")
plt.plot(biases[1, :], label="Bias")
plt.plot(variances[1, :], label="Variance")
plt.legend()
#plt.savefig("../figures/ridge_bias_variance")

plt.figure()
plt.title("Lasso bias-variance")
plt.plot(errors[1, :], label="Error")
plt.plot(biases[1, :], label="Bias")
plt.plot(variances[1, :], label="Variance")
plt.legend()
#plt.savefig("../figures/lasso_bias_variance")
# Out:
# at polynomial 1 out of 12
# at polynomial 2 out of 12
# at polynomial 3 out of 12
# at polynomial 4 out of 12
# at polynomial 5 out of 12
# at polynomial 6 out of 12
# at polynomial 7 out of 12
# at polynomial 8 out of 12
# at polynomial 9 out of 12
# at polynomial 10 out of 12
# at polynomial 11 out of 12
# at polynomial 12 out of 12

# %% [markdown]
# ### MLP

# %%
test_size = 0.2
n_bootstraps = 100

x = x.ravel()
y = y.ravel()
z = z.ravel().reshape(-1,1)
x_train, x_test, y_train, y_test, z_train, z_test = train_test_split(x, y, z, test_size=test_size)

l2_arr = [0, 10e-20, 10e-7, 10e-4, 10e-2, 1, 2, 4, 8, 10]

length = len(l2_arr)

errors = np.zeros(length)
biases = np.zeros(length)
variances = np.zeros(length)


for iter,l2 in enumerate(l2_arr):
    print(f"at l2 {l2}, iter {iter} out of {len(l2_arr)}")
    
    # Creating design matrix 
    X_train = create_design_matrix(x_train, y_train, 1)

    X_test = create_design_matrix(x_test, y_test, 1)
    
    predictions = np.zeros((len(z_test), n_bootstraps))

    model = MLPRegressor(alpha=l2, max_iter=1000, learning_rate="adaptive")
    for i in range(n_bootstraps):
        X_, z_ = resample(X_train, z_train)
        # Creating a fit for the models with the data
        model.fit(X_, z_)

        # Creating predictions with the models
        predictions[:, i] = model.predict(X_test).ravel()


    errors[iter] = np.mean(np.mean((z_test - predictions)**2, axis=1, keepdims=True))
    biases[iter] = np.mean((z_test - np.mean(predictions, axis=1, keepdims=True))**2)
    variances[iter] = np.mean( np.var(predictions, axis=1, keepdims=True))

plt.figure()
plt.title("MLP bias-variance")
plt.plot(errors, label="Error")
plt.plot(biases, label="Bias")
plt.plot(variances, label="Variance")
plt.legend()
plt.savefig("../figures/MLP_bias_variance_layers")
# Out:
# at l2 0, iter 0 out of 10
# at l2 1e-19, iter 1 out of 10
# at l2 1e-06, iter 2 out of 10
# at l2 0.001, iter 3 out of 10
# at l2 0.1, iter 4 out of 10
# at l2 1, iter 5 out of 10
# at l2 2, iter 6 out of 10
# at l2 4, iter 7 out of 10
# at l2 8, iter 8 out of 10
# at l2 10, iter 9 out of 10

# %%
test_size = 0.2
n_bootstraps = 100

x = x.ravel()
y = y.ravel()
z = z.ravel().reshape(-1,1)
x_train, x_test, y_train, y_test, z_train, z_test = train_test_split(x, y, z, test_size=test_size)

N = 20
M = 10
layers=[np.random.randint(N, size=i)+1 for i in range(M)]

length = M

errors = np.zeros(length)
biases = np.zeros(length)
variances = np.zeros(length)


for iter,layer in enumerate(layers):
    print(layer)
    print(f"at iter {iter} out of {M}")
    
    # Creating design matrix 
    X_train = create_design_matrix(x_train, y_train, 1)

    X_test = create_design_matrix(x_test, y_test, 1)
    
    predictions = np.zeros((len(z_test), n_bootstraps))

    model = MLPRegressor(max_iter=1000, hidden_layer_sizes=layer)
    for i in range(n_bootstraps):
        X_, z_ = resample(X_train, z_train)
        # Creating a fit for the models with the data
        model.fit(X_, z_)

        # Creating predictions with the models
        predictions[:, i] = model.predict(X_test).ravel()


    errors[iter] = np.mean(np.mean((z_test - predictions)**2, axis=1, keepdims=True))
    biases[iter] = np.mean((z_test - np.mean(predictions, axis=1, keepdims=True))**2)
    variances[iter] = np.mean( np.var(predictions, axis=1, keepdims=True))

plt.figure()
plt.title("MLP bias-variance")
plt.plot(errors, label="Error")
plt.plot(biases, label="Bias")
plt.plot(variances, label="Variance")
plt.legend()
plt.savefig("../figures/MLP_bias_variance_layers")
# Out:
# []
# at iter 0 out of 10
# [5]
# at iter 1 out of 10
# [13  9]
# at iter 2 out of 10
# [20 15 15]
# at iter 3 out of 10
# [10 14 20  3]
# at iter 4 out of 10
# [ 1  9 14 10 19]
# at iter 5 out of 10
# [20 12  8  8 17  8]
# at iter 6 out of 10
# [ 4 14  3 14  7 16  7]
# at iter 7 out of 10
# [ 8  7  6  7  4 19  9 15]
# at iter 8 out of 10
# [ 6 13 18  4 18 20  3 12 13]
# at iter 9 out of 10

# %% [markdown]
# ### Random forests

# %%
X = create_design_matrix(x, y, 1)
X_train, X_test, y_train, y_test = train_test_split(X, z.ravel(), test_size=test_size)

complexity = np.arange(0, 100) * 1 + 2

errors = np.zeros(len(complexity))
biases = np.zeros(len(complexity))
variances = np.zeros(len(complexity))

for i, current_complexity in enumerate(complexity):
    forest = RandomForestRegressor(random_state = 1, bootstrap = True, n_jobs=-1, min_samples_leaf=current_complexity)
    forest.fit(X_train, y_train)

    prediction = forest.predict(X_test)

    errors[i] = np.mean(np.mean((y_test - prediction)**2, axis=0, keepdims=True))
    biases[i] = np.mean((y_test - np.mean(prediction, axis=0, keepdims=True))**2)
    variances[i] = np.mean( np.var(prediction, axis=0, keepdims=True))

    print(f"Progress: {i} / {len(complexity)} iterations")

plt.figure()
plt.title("Random forests bias-variance")
plt.plot(errors, label="Error")
plt.plot(biases, label="Bias")
plt.plot(variances, label="Variance")
plt.xlabel("Min samples leaf")
plt.ylabel("Error, bias, variance")
plt.legend()
plt.savefig("../figures/random_forests_bias_variance")
# Out:
# Progress: 0 / 100 iterations
# Progress: 1 / 100 iterations
# Progress: 2 / 100 iterations
# Progress: 3 / 100 iterations
# Progress: 4 / 100 iterations
# Progress: 5 / 100 iterations
# Progress: 6 / 100 iterations
# Progress: 7 / 100 iterations
# Progress: 8 / 100 iterations
# Progress: 9 / 100 iterations
# Progress: 10 / 100 iterations
# Progress: 11 / 100 iterations
# Progress: 12 / 100 iterations
# Progress: 13 / 100 iterations
# Progress: 14 / 100 iterations
# Progress: 15 / 100 iterations
# Progress: 16 / 100 iterations
# Progress: 17 / 100 iterations
# Progress: 18 / 100 iterations
# Progress: 19 / 100 iterations
# Progress: 20 / 100 iterations
# Progress: 21 / 100 iterations
# Progress: 22 / 100 iterations
# Progress: 23 / 100 iterations
# Progress: 24 / 100 iterations
# Progress: 25 / 100 iterations
# Progress: 26 / 100 iterations
# Progress: 27 / 100 iterations
# Progress: 28 / 100 iterations
# Progress: 29 / 100 iterations
# Progress: 30 / 100 iterations
# Progress: 31 / 100 iterations
# Progress: 32 / 100 iterations
# Progress: 33 / 100 iterations
# Progress: 34 / 100 iterations
# Progress: 35 / 100 iterations
# Progress: 36 / 100 iterations
# Progress: 37 / 100 iterations
# Progress: 38 / 100 iterations
# Progress: 39 / 100 iterations
# Progress: 40 / 100 iterations
# Progress: 41 / 100 iterations
# Progress: 42 / 100 iterations
# Progress: 43 / 100 iterations
# Progress: 44 / 100 iterations
# Progress: 45 / 100 iterations
# Progress: 46 / 100 iterations
# Progress: 47 / 100 iterations
# Progress: 48 / 100 iterations
# Progress: 49 / 100 iterations
# Progress: 50 / 100 iterations
# Progress: 51 / 100 iterations
# Progress: 52 / 100 iterations
# Progress: 53 / 100 iterations
# Progress: 54 / 100 iterations
# Progress: 55 / 100 iterations
# Progress: 56 / 100 iterations
# Progress: 57 / 100 iterations
# Progress: 58 / 100 iterations
# Progress: 59 / 100 iterations
# Progress: 60 / 100 iterations
# Progress: 61 / 100 iterations
# Progress: 62 / 100 iterations
# Progress: 63 / 100 iterations
# Progress: 64 / 100 iterations
# Progress: 65 / 100 iterations
# Progress: 66 / 100 iterations
# Progress: 67 / 100 iterations
# Progress: 68 / 100 iterations
# Progress: 69 / 100 iterations
# Progress: 70 / 100 iterations
# Progress: 71 / 100 iterations
# Progress: 72 / 100 iterations
# Progress: 73 / 100 iterations
# Progress: 74 / 100 iterations
# Progress: 75 / 100 iterations
# Progress: 76 / 100 iterations
# Progress: 77 / 100 iterations
# Progress: 78 / 100 iterations
# Progress: 79 / 100 iterations
# Progress: 80 / 100 iterations
# Progress: 81 / 100 iterations
# Progress: 82 / 100 iterations
# Progress: 83 / 100 iterations
# Progress: 84 / 100 iterations
# Progress: 85 / 100 iterations
# Progress: 86 / 100 iterations
# Progress: 87 / 100 iterations
# Progress: 88 / 100 iterations
# Progress: 89 / 100 iterations
# Progress: 90 / 100 iterations
# Progress: 91 / 100 iterations
# Progress: 92 / 100 iterations
# Progress: 93 / 100 iterations
# Progress: 94 / 100 iterations
# Progress: 95 / 100 iterations
# Progress: 96 / 100 iterations
# Progress: 97 / 100 iterations
# Progress: 98 / 100 iterations
# Progress: 99 / 100 iterations
